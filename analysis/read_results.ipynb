# %%
import pickle as pkl
import json
import numpy as np
import pandas as pd
from scipy import stats
from pathlib import Path

# %%
import sys
import os

src_path = os.path.abspath('../src')
parent_path = os.path.dirname(src_path)
sys.path.insert(0, parent_path)

# %%
# unzip results file
# !unzip results/results_files.zip -d results/
# Out:
# Archive:  results/results_files.zip
#    creating: results/baselines_classification/
#    creating: results/baselines_regression/
#    creating: results/llego_classification/
#    creating: results/llego_regression/
#    creating: results/baselines_classification/3/
#    creating: results/baselines_classification/3/credit-g/
#    creating: results/baselines_classification/3/credit-g/C45/
#   inflating: results/baselines_classification/3/credit-g/C45/results_seed_3.json
#   inflating: results/baselines_classification/3/credit-g/C45/results_seed_0.json
#   inflating: results/baselines_classification/3/credit-g/C45/results_seed_1.json
#   inflating: results/baselines_classification/3/credit-g/C45/results_seed_2.json
#   inflating: results/baselines_classification/3/credit-g/C45/results_seed_4.json
#    creating: results/baselines_classification/3/credit-g/GATREE/
#  extracting: results/baselines_classification/3/credit-g/GATREE/debug.ipynb
#   inflating: results/baselines_classification/3/credit-g/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_classification/3/credit-g/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_classification/3/credit-g/GATREE/gatree_search_populations.pkl
#   inflating: results/baselines_classification/3/credit-g/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_classification/3/credit-g/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_classification/3/credit-g/GATREE/gatree_config.yaml
#   inflating: results/baselines_classification/3/credit-g/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_classification/3/credit-g/GATREE/gatree_hof.pkl
#   inflating: results/baselines_classification/3/credit-g/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_classification/3/credit-g/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_classification/3/credit-g/GATREE/gatree_hof_seed_3.pkl
#   inflating: results/baselines_classification/3/credit-g/GATREE/gatree_search_populations_seed_3.pkl
#   inflating: results/baselines_classification/3/credit-g/GATREE/gatree_search_populations_seed_1.pkl
#    creating: results/baselines_classification/3/credit-g/DL85/
#   inflating: results/baselines_classification/3/credit-g/DL85/results_seed_3.json
#   inflating: results/baselines_classification/3/credit-g/DL85/results_seed_0.json
#   inflating: results/baselines_classification/3/credit-g/DL85/results_seed_1.json
#   inflating: results/baselines_classification/3/credit-g/DL85/results_seed_2.json
#   inflating: results/baselines_classification/3/credit-g/DL85/results_seed_4.json
#    creating: results/baselines_classification/3/credit-g/CART/
#   inflating: results/baselines_classification/3/credit-g/CART/debug.ipynb
#   inflating: results/baselines_classification/3/credit-g/CART/results_seed_3.json
#   inflating: results/baselines_classification/3/credit-g/CART/results_seed_0.json
#   inflating: results/baselines_classification/3/credit-g/CART/results_seed_1.json
#   inflating: results/baselines_classification/3/credit-g/CART/results_seed_2.json
#   inflating: results/baselines_classification/3/credit-g/CART/results_seed_4.json
#    creating: results/baselines_classification/3/credit-g/GOSDT/
#   inflating: results/baselines_classification/3/credit-g/GOSDT/results_seed_3.json
#   inflating: results/baselines_classification/3/credit-g/GOSDT/results_seed_0.json
#   inflating: results/baselines_classification/3/credit-g/GOSDT/results_seed_1.json
#   inflating: results/baselines_classification/3/credit-g/GOSDT/results_seed_2.json
#   inflating: results/baselines_classification/3/credit-g/GOSDT/results_seed_4.json
#    creating: results/baselines_classification/3/compas/
#    creating: results/baselines_classification/3/compas/C45/
#   inflating: results/baselines_classification/3/compas/C45/results_seed_3.json
#   inflating: results/baselines_classification/3/compas/C45/results_seed_0.json
#   inflating: results/baselines_classification/3/compas/C45/results_seed_1.json
#   inflating: results/baselines_classification/3/compas/C45/results_seed_2.json
#   inflating: results/baselines_classification/3/compas/C45/results_seed_4.json
#    creating: results/baselines_classification/3/compas/GATREE/
#   inflating: results/baselines_classification/3/compas/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_classification/3/compas/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_classification/3/compas/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_classification/3/compas/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_classification/3/compas/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_classification/3/compas/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_classification/3/compas/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_classification/3/compas/GATREE/gatree_hof_seed_3.pkl
#   inflating: results/baselines_classification/3/compas/GATREE/gatree_search_populations_seed_3.pkl
#   inflating: results/baselines_classification/3/compas/GATREE/gatree_search_populations_seed_1.pkl
#    creating: results/baselines_classification/3/compas/DL85/
#   inflating: results/baselines_classification/3/compas/DL85/results_seed_3.json
#   inflating: results/baselines_classification/3/compas/DL85/results_seed_0.json
#   inflating: results/baselines_classification/3/compas/DL85/results_seed_1.json
#   inflating: results/baselines_classification/3/compas/DL85/results_seed_2.json
#   inflating: results/baselines_classification/3/compas/DL85/results_seed_4.json
#    creating: results/baselines_classification/3/compas/CART/
#   inflating: results/baselines_classification/3/compas/CART/results_seed_3.json
#   inflating: results/baselines_classification/3/compas/CART/results_seed_0.json
#   inflating: results/baselines_classification/3/compas/CART/results_seed_1.json
#   inflating: results/baselines_classification/3/compas/CART/results_seed_2.json
#   inflating: results/baselines_classification/3/compas/CART/results_seed_4.json
#    creating: results/baselines_classification/3/compas/GOSDT/
#   inflating: results/baselines_classification/3/compas/GOSDT/results_seed_3.json
#   inflating: results/baselines_classification/3/compas/GOSDT/results_seed_0.json
#   inflating: results/baselines_classification/3/compas/GOSDT/results_seed_1.json
#   inflating: results/baselines_classification/3/compas/GOSDT/results_seed_2.json
#   inflating: results/baselines_classification/3/compas/GOSDT/results_seed_4.json
#    creating: results/baselines_classification/3/liver/
#    creating: results/baselines_classification/3/liver/C45/
#   inflating: results/baselines_classification/3/liver/C45/results_seed_3.json
#   inflating: results/baselines_classification/3/liver/C45/results_seed_0.json
#   inflating: results/baselines_classification/3/liver/C45/results_seed_1.json
#   inflating: results/baselines_classification/3/liver/C45/results_seed_2.json
#   inflating: results/baselines_classification/3/liver/C45/results_seed_4.json
#    creating: results/baselines_classification/3/liver/GATREE/
#   inflating: results/baselines_classification/3/liver/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_classification/3/liver/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_classification/3/liver/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_classification/3/liver/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_classification/3/liver/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_classification/3/liver/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_classification/3/liver/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_classification/3/liver/GATREE/gatree_hof_seed_3.pkl
#   inflating: results/baselines_classification/3/liver/GATREE/gatree_search_populations_seed_3.pkl
#   inflating: results/baselines_classification/3/liver/GATREE/gatree_search_populations_seed_1.pkl
#    creating: results/baselines_classification/3/liver/DL85/
#   inflating: results/baselines_classification/3/liver/DL85/results_seed_3.json
#   inflating: results/baselines_classification/3/liver/DL85/results_seed_0.json
#   inflating: results/baselines_classification/3/liver/DL85/results_seed_1.json
#   inflating: results/baselines_classification/3/liver/DL85/results_seed_2.json
#   inflating: results/baselines_classification/3/liver/DL85/results_seed_4.json
#    creating: results/baselines_classification/3/liver/CART/
#   inflating: results/baselines_classification/3/liver/CART/results_seed_3.json
#   inflating: results/baselines_classification/3/liver/CART/results_seed_0.json
#   inflating: results/baselines_classification/3/liver/CART/results_seed_1.json
#   inflating: results/baselines_classification/3/liver/CART/results_seed_2.json
#   inflating: results/baselines_classification/3/liver/CART/results_seed_4.json
#    creating: results/baselines_classification/3/liver/GOSDT/
#   inflating: results/baselines_classification/3/liver/GOSDT/results_seed_3.json
#   inflating: results/baselines_classification/3/liver/GOSDT/results_seed_0.json
#   inflating: results/baselines_classification/3/liver/GOSDT/results_seed_1.json
#   inflating: results/baselines_classification/3/liver/GOSDT/results_seed_2.json
#   inflating: results/baselines_classification/3/liver/GOSDT/results_seed_4.json
#    creating: results/baselines_classification/3/diabetes/
#    creating: results/baselines_classification/3/diabetes/C45/
#   inflating: results/baselines_classification/3/diabetes/C45/results_seed_3.json
#   inflating: results/baselines_classification/3/diabetes/C45/results_seed_0.json
#   inflating: results/baselines_classification/3/diabetes/C45/results_seed_1.json
#   inflating: results/baselines_classification/3/diabetes/C45/results_seed_2.json
#   inflating: results/baselines_classification/3/diabetes/C45/results_seed_4.json
#    creating: results/baselines_classification/3/diabetes/GATREE/
#   inflating: results/baselines_classification/3/diabetes/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_classification/3/diabetes/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_classification/3/diabetes/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_classification/3/diabetes/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_classification/3/diabetes/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_classification/3/diabetes/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_classification/3/diabetes/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_classification/3/diabetes/GATREE/gatree_hof_seed_3.pkl
#   inflating: results/baselines_classification/3/diabetes/GATREE/gatree_search_populations_seed_3.pkl
#   inflating: results/baselines_classification/3/diabetes/GATREE/gatree_search_populations_seed_1.pkl
#    creating: results/baselines_classification/3/diabetes/DL85/
#   inflating: results/baselines_classification/3/diabetes/DL85/results_seed_3.json
#   inflating: results/baselines_classification/3/diabetes/DL85/results_seed_0.json
#   inflating: results/baselines_classification/3/diabetes/DL85/results_seed_1.json
#   inflating: results/baselines_classification/3/diabetes/DL85/results_seed_2.json
#   inflating: results/baselines_classification/3/diabetes/DL85/results_seed_4.json
#    creating: results/baselines_classification/3/diabetes/CART/
#   inflating: results/baselines_classification/3/diabetes/CART/results_seed_3.json
#   inflating: results/baselines_classification/3/diabetes/CART/results_seed_0.json
#   inflating: results/baselines_classification/3/diabetes/CART/results_seed_1.json
#   inflating: results/baselines_classification/3/diabetes/CART/results_seed_2.json
#   inflating: results/baselines_classification/3/diabetes/CART/results_seed_4.json
#    creating: results/baselines_classification/3/diabetes/GOSDT/
#   inflating: results/baselines_classification/3/diabetes/GOSDT/results_seed_3.json
#   inflating: results/baselines_classification/3/diabetes/GOSDT/results_seed_0.json
#   inflating: results/baselines_classification/3/diabetes/GOSDT/results_seed_1.json
#   inflating: results/baselines_classification/3/diabetes/GOSDT/results_seed_2.json
#   inflating: results/baselines_classification/3/diabetes/GOSDT/results_seed_4.json
#    creating: results/baselines_classification/3/breast/
#    creating: results/baselines_classification/3/breast/C45/
#   inflating: results/baselines_classification/3/breast/C45/results_seed_3.json
#   inflating: results/baselines_classification/3/breast/C45/results_seed_0.json
#   inflating: results/baselines_classification/3/breast/C45/results_seed_1.json
#   inflating: results/baselines_classification/3/breast/C45/results_seed_2.json
#   inflating: results/baselines_classification/3/breast/C45/results_seed_4.json
#    creating: results/baselines_classification/3/breast/GATREE/
#   inflating: results/baselines_classification/3/breast/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_classification/3/breast/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_classification/3/breast/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_classification/3/breast/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_classification/3/breast/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_classification/3/breast/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_classification/3/breast/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_classification/3/breast/GATREE/gatree_hof_seed_3.pkl
#   inflating: results/baselines_classification/3/breast/GATREE/gatree_search_populations_seed_3.pkl
#   inflating: results/baselines_classification/3/breast/GATREE/gatree_search_populations_seed_1.pkl
#    creating: results/baselines_classification/3/breast/DL85/
#   inflating: results/baselines_classification/3/breast/DL85/results_seed_3.json
#   inflating: results/baselines_classification/3/breast/DL85/results_seed_0.json
#   inflating: results/baselines_classification/3/breast/DL85/results_seed_1.json
#   inflating: results/baselines_classification/3/breast/DL85/results_seed_2.json
#   inflating: results/baselines_classification/3/breast/DL85/results_seed_4.json
#    creating: results/baselines_classification/3/breast/CART/
#   inflating: results/baselines_classification/3/breast/CART/results_seed_3.json
#   inflating: results/baselines_classification/3/breast/CART/results_seed_0.json
#   inflating: results/baselines_classification/3/breast/CART/results_seed_1.json
#   inflating: results/baselines_classification/3/breast/CART/results_seed_2.json
#   inflating: results/baselines_classification/3/breast/CART/results_seed_4.json
#    creating: results/baselines_classification/3/breast/GOSDT/
#   inflating: results/baselines_classification/3/breast/GOSDT/results_seed_3.json
#   inflating: results/baselines_classification/3/breast/GOSDT/results_seed_0.json
#   inflating: results/baselines_classification/3/breast/GOSDT/results_seed_1.json
#   inflating: results/baselines_classification/3/breast/GOSDT/results_seed_2.json
#   inflating: results/baselines_classification/3/breast/GOSDT/results_seed_4.json
#    creating: results/baselines_classification/3/heart-statlog/
#    creating: results/baselines_classification/3/heart-statlog/C45/
#   inflating: results/baselines_classification/3/heart-statlog/C45/results_seed_3.json
#   inflating: results/baselines_classification/3/heart-statlog/C45/results_seed_0.json
#   inflating: results/baselines_classification/3/heart-statlog/C45/results_seed_1.json
#   inflating: results/baselines_classification/3/heart-statlog/C45/results_seed_2.json
#   inflating: results/baselines_classification/3/heart-statlog/C45/results_seed_4.json
#    creating: results/baselines_classification/3/heart-statlog/GATREE/
#   inflating: results/baselines_classification/3/heart-statlog/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_classification/3/heart-statlog/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_classification/3/heart-statlog/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_classification/3/heart-statlog/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_classification/3/heart-statlog/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_classification/3/heart-statlog/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_classification/3/heart-statlog/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_classification/3/heart-statlog/GATREE/gatree_hof_seed_3.pkl
#   inflating: results/baselines_classification/3/heart-statlog/GATREE/gatree_search_populations_seed_3.pkl
#   inflating: results/baselines_classification/3/heart-statlog/GATREE/gatree_search_populations_seed_1.pkl
#    creating: results/baselines_classification/3/heart-statlog/DL85/
#   inflating: results/baselines_classification/3/heart-statlog/DL85/results_seed_3.json
#   inflating: results/baselines_classification/3/heart-statlog/DL85/results_seed_0.json
#   inflating: results/baselines_classification/3/heart-statlog/DL85/results_seed_1.json
#   inflating: results/baselines_classification/3/heart-statlog/DL85/results_seed_2.json
#   inflating: results/baselines_classification/3/heart-statlog/DL85/results_seed_4.json
#    creating: results/baselines_classification/3/heart-statlog/CART/
#   inflating: results/baselines_classification/3/heart-statlog/CART/results_seed_3.json
#   inflating: results/baselines_classification/3/heart-statlog/CART/results_seed_0.json
#   inflating: results/baselines_classification/3/heart-statlog/CART/results_seed_1.json
#   inflating: results/baselines_classification/3/heart-statlog/CART/results_seed_2.json
#   inflating: results/baselines_classification/3/heart-statlog/CART/results_seed_4.json
#    creating: results/baselines_classification/3/heart-statlog/GOSDT/
#   inflating: results/baselines_classification/3/heart-statlog/GOSDT/results_seed_3.json
#   inflating: results/baselines_classification/3/heart-statlog/GOSDT/results_seed_0.json
#   inflating: results/baselines_classification/3/heart-statlog/GOSDT/results_seed_1.json
#   inflating: results/baselines_classification/3/heart-statlog/GOSDT/results_seed_2.json
#   inflating: results/baselines_classification/3/heart-statlog/GOSDT/results_seed_4.json
#    creating: results/baselines_classification/3/vehicle/
#    creating: results/baselines_classification/3/vehicle/C45/
#   inflating: results/baselines_classification/3/vehicle/C45/results_seed_3.json
#   inflating: results/baselines_classification/3/vehicle/C45/results_seed_0.json
#   inflating: results/baselines_classification/3/vehicle/C45/results_seed_1.json
#   inflating: results/baselines_classification/3/vehicle/C45/results_seed_2.json
#   inflating: results/baselines_classification/3/vehicle/C45/results_seed_4.json
#    creating: results/baselines_classification/3/vehicle/GATREE/
#   inflating: results/baselines_classification/3/vehicle/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_classification/3/vehicle/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_classification/3/vehicle/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_classification/3/vehicle/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_classification/3/vehicle/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_classification/3/vehicle/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_classification/3/vehicle/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_classification/3/vehicle/GATREE/gatree_hof_seed_3.pkl
#   inflating: results/baselines_classification/3/vehicle/GATREE/gatree_search_populations_seed_3.pkl
#   inflating: results/baselines_classification/3/vehicle/GATREE/gatree_search_populations_seed_1.pkl
#    creating: results/baselines_classification/3/vehicle/DL85/
#   inflating: results/baselines_classification/3/vehicle/DL85/results_seed_3.json
#   inflating: results/baselines_classification/3/vehicle/DL85/results_seed_0.json
#   inflating: results/baselines_classification/3/vehicle/DL85/results_seed_1.json
#   inflating: results/baselines_classification/3/vehicle/DL85/results_seed_2.json
#   inflating: results/baselines_classification/3/vehicle/DL85/results_seed_4.json
#    creating: results/baselines_classification/3/vehicle/CART/
#   inflating: results/baselines_classification/3/vehicle/CART/results_seed_3.json
#   inflating: results/baselines_classification/3/vehicle/CART/results_seed_0.json
#   inflating: results/baselines_classification/3/vehicle/CART/results_seed_1.json
#   inflating: results/baselines_classification/3/vehicle/CART/results_seed_2.json
#   inflating: results/baselines_classification/3/vehicle/CART/results_seed_4.json
#    creating: results/baselines_classification/3/vehicle/GOSDT/
#   inflating: results/baselines_classification/3/vehicle/GOSDT/results_seed_3.json
#   inflating: results/baselines_classification/3/vehicle/GOSDT/results_seed_0.json
#   inflating: results/baselines_classification/3/vehicle/GOSDT/results_seed_1.json
#   inflating: results/baselines_classification/3/vehicle/GOSDT/results_seed_2.json
#   inflating: results/baselines_classification/3/vehicle/GOSDT/results_seed_4.json
#    creating: results/baselines_classification/4/
#    creating: results/baselines_classification/4/credit-g/
#    creating: results/baselines_classification/4/credit-g/C45/
#   inflating: results/baselines_classification/4/credit-g/C45/results_seed_3.json
#   inflating: results/baselines_classification/4/credit-g/C45/results_seed_0.json
#   inflating: results/baselines_classification/4/credit-g/C45/results_seed_1.json
#   inflating: results/baselines_classification/4/credit-g/C45/results_seed_2.json
#   inflating: results/baselines_classification/4/credit-g/C45/results_seed_4.json
#    creating: results/baselines_classification/4/credit-g/GATREE/
#   inflating: results/baselines_classification/4/credit-g/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_classification/4/credit-g/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_classification/4/credit-g/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_classification/4/credit-g/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_classification/4/credit-g/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_classification/4/credit-g/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_classification/4/credit-g/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_classification/4/credit-g/GATREE/gatree_hof_seed_3.pkl
#   inflating: results/baselines_classification/4/credit-g/GATREE/gatree_search_populations_seed_3.pkl
#   inflating: results/baselines_classification/4/credit-g/GATREE/gatree_search_populations_seed_1.pkl
#    creating: results/baselines_classification/4/credit-g/DL85/
#   inflating: results/baselines_classification/4/credit-g/DL85/results_seed_3.json
#   inflating: results/baselines_classification/4/credit-g/DL85/results_seed_0.json
#   inflating: results/baselines_classification/4/credit-g/DL85/results_seed_1.json
#   inflating: results/baselines_classification/4/credit-g/DL85/results_seed_2.json
#   inflating: results/baselines_classification/4/credit-g/DL85/results_seed_4.json
#    creating: results/baselines_classification/4/credit-g/CART/
#   inflating: results/baselines_classification/4/credit-g/CART/results_seed_3.json
#   inflating: results/baselines_classification/4/credit-g/CART/results_seed_0.json
#   inflating: results/baselines_classification/4/credit-g/CART/results_seed_1.json
#   inflating: results/baselines_classification/4/credit-g/CART/results_seed_2.json
#   inflating: results/baselines_classification/4/credit-g/CART/results_seed_4.json
#    creating: results/baselines_classification/4/credit-g/GOSDT/
#   inflating: results/baselines_classification/4/credit-g/GOSDT/results_seed_3.json
#   inflating: results/baselines_classification/4/credit-g/GOSDT/results_seed_0.json
#   inflating: results/baselines_classification/4/credit-g/GOSDT/results_seed_1.json
#   inflating: results/baselines_classification/4/credit-g/GOSDT/results_seed_2.json
#   inflating: results/baselines_classification/4/credit-g/GOSDT/results_seed_4.json
#    creating: results/baselines_classification/4/compas/
#    creating: results/baselines_classification/4/compas/C45/
#   inflating: results/baselines_classification/4/compas/C45/results_seed_3.json
#   inflating: results/baselines_classification/4/compas/C45/results_seed_0.json
#   inflating: results/baselines_classification/4/compas/C45/results_seed_1.json
#   inflating: results/baselines_classification/4/compas/C45/results_seed_2.json
#   inflating: results/baselines_classification/4/compas/C45/results_seed_4.json
#    creating: results/baselines_classification/4/compas/GATREE/
#   inflating: results/baselines_classification/4/compas/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_classification/4/compas/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_classification/4/compas/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_classification/4/compas/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_classification/4/compas/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_classification/4/compas/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_classification/4/compas/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_classification/4/compas/GATREE/gatree_hof_seed_3.pkl
#   inflating: results/baselines_classification/4/compas/GATREE/gatree_search_populations_seed_3.pkl
#   inflating: results/baselines_classification/4/compas/GATREE/gatree_search_populations_seed_1.pkl
#    creating: results/baselines_classification/4/compas/DL85/
#   inflating: results/baselines_classification/4/compas/DL85/results_seed_3.json
#   inflating: results/baselines_classification/4/compas/DL85/results_seed_0.json
#   inflating: results/baselines_classification/4/compas/DL85/results_seed_1.json
#   inflating: results/baselines_classification/4/compas/DL85/results_seed_2.json
#   inflating: results/baselines_classification/4/compas/DL85/results_seed_4.json
#    creating: results/baselines_classification/4/compas/CART/
#   inflating: results/baselines_classification/4/compas/CART/results_seed_3.json
#   inflating: results/baselines_classification/4/compas/CART/results_seed_0.json
#   inflating: results/baselines_classification/4/compas/CART/results_seed_1.json
#   inflating: results/baselines_classification/4/compas/CART/results_seed_2.json
#   inflating: results/baselines_classification/4/compas/CART/results_seed_4.json
#    creating: results/baselines_classification/4/compas/GOSDT/
#   inflating: results/baselines_classification/4/compas/GOSDT/results_seed_3.json
#   inflating: results/baselines_classification/4/compas/GOSDT/results_seed_0.json
#   inflating: results/baselines_classification/4/compas/GOSDT/results_seed_1.json
#   inflating: results/baselines_classification/4/compas/GOSDT/results_seed_2.json
#   inflating: results/baselines_classification/4/compas/GOSDT/results_seed_4.json
#    creating: results/baselines_classification/4/liver/
#    creating: results/baselines_classification/4/liver/C45/
#   inflating: results/baselines_classification/4/liver/C45/results_seed_3.json
#   inflating: results/baselines_classification/4/liver/C45/results_seed_0.json
#   inflating: results/baselines_classification/4/liver/C45/results_seed_1.json
#   inflating: results/baselines_classification/4/liver/C45/results_seed_2.json
#   inflating: results/baselines_classification/4/liver/C45/results_seed_4.json
#    creating: results/baselines_classification/4/liver/GATREE/
#   inflating: results/baselines_classification/4/liver/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_classification/4/liver/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_classification/4/liver/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_classification/4/liver/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_classification/4/liver/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_classification/4/liver/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_classification/4/liver/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_classification/4/liver/GATREE/gatree_hof_seed_3.pkl
#   inflating: results/baselines_classification/4/liver/GATREE/gatree_search_populations_seed_3.pkl
#   inflating: results/baselines_classification/4/liver/GATREE/gatree_search_populations_seed_1.pkl
#    creating: results/baselines_classification/4/liver/DL85/
#   inflating: results/baselines_classification/4/liver/DL85/results_seed_3.json
#   inflating: results/baselines_classification/4/liver/DL85/results_seed_0.json
#   inflating: results/baselines_classification/4/liver/DL85/results_seed_1.json
#   inflating: results/baselines_classification/4/liver/DL85/results_seed_2.json
#   inflating: results/baselines_classification/4/liver/DL85/results_seed_4.json
#    creating: results/baselines_classification/4/liver/CART/
#   inflating: results/baselines_classification/4/liver/CART/results_seed_3.json
#   inflating: results/baselines_classification/4/liver/CART/results_seed_0.json
#   inflating: results/baselines_classification/4/liver/CART/results_seed_1.json
#   inflating: results/baselines_classification/4/liver/CART/results_seed_2.json
#   inflating: results/baselines_classification/4/liver/CART/results_seed_4.json
#    creating: results/baselines_classification/4/liver/GOSDT/
#   inflating: results/baselines_classification/4/liver/GOSDT/results_seed_3.json
#   inflating: results/baselines_classification/4/liver/GOSDT/results_seed_0.json
#   inflating: results/baselines_classification/4/liver/GOSDT/results_seed_1.json
#   inflating: results/baselines_classification/4/liver/GOSDT/results_seed_2.json
#   inflating: results/baselines_classification/4/liver/GOSDT/results_seed_4.json
#    creating: results/baselines_classification/4/diabetes/
#    creating: results/baselines_classification/4/diabetes/C45/
#   inflating: results/baselines_classification/4/diabetes/C45/results_seed_3.json
#   inflating: results/baselines_classification/4/diabetes/C45/results_seed_0.json
#   inflating: results/baselines_classification/4/diabetes/C45/results_seed_1.json
#   inflating: results/baselines_classification/4/diabetes/C45/results_seed_2.json
#   inflating: results/baselines_classification/4/diabetes/C45/results_seed_4.json
#    creating: results/baselines_classification/4/diabetes/GATREE/
#   inflating: results/baselines_classification/4/diabetes/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_classification/4/diabetes/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_classification/4/diabetes/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_classification/4/diabetes/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_classification/4/diabetes/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_classification/4/diabetes/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_classification/4/diabetes/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_classification/4/diabetes/GATREE/gatree_hof_seed_3.pkl
#   inflating: results/baselines_classification/4/diabetes/GATREE/gatree_search_populations_seed_3.pkl
#   inflating: results/baselines_classification/4/diabetes/GATREE/gatree_search_populations_seed_1.pkl
#    creating: results/baselines_classification/4/diabetes/DL85/
#   inflating: results/baselines_classification/4/diabetes/DL85/results_seed_3.json
#   inflating: results/baselines_classification/4/diabetes/DL85/results_seed_0.json
#   inflating: results/baselines_classification/4/diabetes/DL85/results_seed_1.json
#   inflating: results/baselines_classification/4/diabetes/DL85/results_seed_2.json
#   inflating: results/baselines_classification/4/diabetes/DL85/results_seed_4.json
#    creating: results/baselines_classification/4/diabetes/CART/
#   inflating: results/baselines_classification/4/diabetes/CART/results_seed_3.json
#   inflating: results/baselines_classification/4/diabetes/CART/results_seed_0.json
#   inflating: results/baselines_classification/4/diabetes/CART/results_seed_1.json
#   inflating: results/baselines_classification/4/diabetes/CART/results_seed_2.json
#   inflating: results/baselines_classification/4/diabetes/CART/results_seed_4.json
#    creating: results/baselines_classification/4/diabetes/GOSDT/
#   inflating: results/baselines_classification/4/diabetes/GOSDT/results_seed_3.json
#   inflating: results/baselines_classification/4/diabetes/GOSDT/results_seed_0.json
#   inflating: results/baselines_classification/4/diabetes/GOSDT/results_seed_1.json
#   inflating: results/baselines_classification/4/diabetes/GOSDT/results_seed_2.json
#   inflating: results/baselines_classification/4/diabetes/GOSDT/results_seed_4.json
#    creating: results/baselines_classification/4/breast/
#    creating: results/baselines_classification/4/breast/C45/
#   inflating: results/baselines_classification/4/breast/C45/results_seed_3.json
#   inflating: results/baselines_classification/4/breast/C45/results_seed_0.json
#   inflating: results/baselines_classification/4/breast/C45/results_seed_1.json
#   inflating: results/baselines_classification/4/breast/C45/results_seed_2.json
#   inflating: results/baselines_classification/4/breast/C45/results_seed_4.json
#    creating: results/baselines_classification/4/breast/GATREE/
#   inflating: results/baselines_classification/4/breast/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_classification/4/breast/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_classification/4/breast/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_classification/4/breast/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_classification/4/breast/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_classification/4/breast/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_classification/4/breast/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_classification/4/breast/GATREE/gatree_hof_seed_3.pkl
#   inflating: results/baselines_classification/4/breast/GATREE/gatree_search_populations_seed_3.pkl
#   inflating: results/baselines_classification/4/breast/GATREE/gatree_search_populations_seed_1.pkl
#    creating: results/baselines_classification/4/breast/DL85/
#   inflating: results/baselines_classification/4/breast/DL85/results_seed_3.json
#   inflating: results/baselines_classification/4/breast/DL85/results_seed_0.json
#   inflating: results/baselines_classification/4/breast/DL85/results_seed_1.json
#   inflating: results/baselines_classification/4/breast/DL85/results_seed_2.json
#   inflating: results/baselines_classification/4/breast/DL85/results_seed_4.json
#    creating: results/baselines_classification/4/breast/CART/
#   inflating: results/baselines_classification/4/breast/CART/results_seed_3.json
#   inflating: results/baselines_classification/4/breast/CART/results_seed_0.json
#   inflating: results/baselines_classification/4/breast/CART/results_seed_1.json
#   inflating: results/baselines_classification/4/breast/CART/results_seed_2.json
#   inflating: results/baselines_classification/4/breast/CART/results_seed_4.json
#    creating: results/baselines_classification/4/breast/GOSDT/
#   inflating: results/baselines_classification/4/breast/GOSDT/results_seed_3.json
#   inflating: results/baselines_classification/4/breast/GOSDT/results_seed_0.json
#   inflating: results/baselines_classification/4/breast/GOSDT/results_seed_1.json
#   inflating: results/baselines_classification/4/breast/GOSDT/results_seed_2.json
#   inflating: results/baselines_classification/4/breast/GOSDT/results_seed_4.json
#    creating: results/baselines_classification/4/heart-statlog/
#    creating: results/baselines_classification/4/heart-statlog/C45/
#   inflating: results/baselines_classification/4/heart-statlog/C45/results_seed_3.json
#   inflating: results/baselines_classification/4/heart-statlog/C45/results_seed_0.json
#   inflating: results/baselines_classification/4/heart-statlog/C45/results_seed_1.json
#   inflating: results/baselines_classification/4/heart-statlog/C45/results_seed_2.json
#   inflating: results/baselines_classification/4/heart-statlog/C45/results_seed_4.json
#    creating: results/baselines_classification/4/heart-statlog/GATREE/
#   inflating: results/baselines_classification/4/heart-statlog/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_classification/4/heart-statlog/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_classification/4/heart-statlog/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_classification/4/heart-statlog/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_classification/4/heart-statlog/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_classification/4/heart-statlog/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_classification/4/heart-statlog/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_classification/4/heart-statlog/GATREE/gatree_hof_seed_3.pkl
#   inflating: results/baselines_classification/4/heart-statlog/GATREE/gatree_search_populations_seed_3.pkl
#   inflating: results/baselines_classification/4/heart-statlog/GATREE/gatree_search_populations_seed_1.pkl
#    creating: results/baselines_classification/4/heart-statlog/DL85/
#   inflating: results/baselines_classification/4/heart-statlog/DL85/results_seed_3.json
#   inflating: results/baselines_classification/4/heart-statlog/DL85/results_seed_0.json
#   inflating: results/baselines_classification/4/heart-statlog/DL85/results_seed_1.json
#   inflating: results/baselines_classification/4/heart-statlog/DL85/results_seed_2.json
#   inflating: results/baselines_classification/4/heart-statlog/DL85/results_seed_4.json
#    creating: results/baselines_classification/4/heart-statlog/CART/
#   inflating: results/baselines_classification/4/heart-statlog/CART/results_seed_3.json
#   inflating: results/baselines_classification/4/heart-statlog/CART/results_seed_0.json
#   inflating: results/baselines_classification/4/heart-statlog/CART/results_seed_1.json
#   inflating: results/baselines_classification/4/heart-statlog/CART/results_seed_2.json
#   inflating: results/baselines_classification/4/heart-statlog/CART/results_seed_4.json
#    creating: results/baselines_classification/4/heart-statlog/GOSDT/
#   inflating: results/baselines_classification/4/heart-statlog/GOSDT/results_seed_3.json
#   inflating: results/baselines_classification/4/heart-statlog/GOSDT/results_seed_0.json
#   inflating: results/baselines_classification/4/heart-statlog/GOSDT/results_seed_1.json
#   inflating: results/baselines_classification/4/heart-statlog/GOSDT/results_seed_2.json
#   inflating: results/baselines_classification/4/heart-statlog/GOSDT/results_seed_4.json
#    creating: results/baselines_classification/4/vehicle/
#    creating: results/baselines_classification/4/vehicle/C45/
#   inflating: results/baselines_classification/4/vehicle/C45/results_seed_3.json
#   inflating: results/baselines_classification/4/vehicle/C45/results_seed_0.json
#   inflating: results/baselines_classification/4/vehicle/C45/results_seed_1.json
#   inflating: results/baselines_classification/4/vehicle/C45/results_seed_2.json
#   inflating: results/baselines_classification/4/vehicle/C45/results_seed_4.json
#    creating: results/baselines_classification/4/vehicle/GATREE/
#   inflating: results/baselines_classification/4/vehicle/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_classification/4/vehicle/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_classification/4/vehicle/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_classification/4/vehicle/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_classification/4/vehicle/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_classification/4/vehicle/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_classification/4/vehicle/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_classification/4/vehicle/GATREE/gatree_hof_seed_3.pkl
#   inflating: results/baselines_classification/4/vehicle/GATREE/gatree_search_populations_seed_3.pkl
#   inflating: results/baselines_classification/4/vehicle/GATREE/gatree_search_populations_seed_1.pkl
#    creating: results/baselines_classification/4/vehicle/DL85/
#   inflating: results/baselines_classification/4/vehicle/DL85/results_seed_3.json
#   inflating: results/baselines_classification/4/vehicle/DL85/results_seed_0.json
#   inflating: results/baselines_classification/4/vehicle/DL85/results_seed_1.json
#   inflating: results/baselines_classification/4/vehicle/DL85/results_seed_2.json
#   inflating: results/baselines_classification/4/vehicle/DL85/results_seed_4.json
#    creating: results/baselines_classification/4/vehicle/CART/
#   inflating: results/baselines_classification/4/vehicle/CART/results_seed_3.json
#   inflating: results/baselines_classification/4/vehicle/CART/results_seed_0.json
#   inflating: results/baselines_classification/4/vehicle/CART/results_seed_1.json
#   inflating: results/baselines_classification/4/vehicle/CART/results_seed_2.json
#   inflating: results/baselines_classification/4/vehicle/CART/results_seed_4.json
#    creating: results/baselines_classification/4/vehicle/GOSDT/
#   inflating: results/baselines_classification/4/vehicle/GOSDT/results_seed_3.json
#   inflating: results/baselines_classification/4/vehicle/GOSDT/results_seed_0.json
#   inflating: results/baselines_classification/4/vehicle/GOSDT/results_seed_1.json
#   inflating: results/baselines_classification/4/vehicle/GOSDT/results_seed_2.json
#   inflating: results/baselines_classification/4/vehicle/GOSDT/results_seed_4.json
#    creating: results/baselines_regression/3/
#    creating: results/baselines_regression/3/abalone/
#    creating: results/baselines_regression/3/abalone/GATREE/
#   inflating: results/baselines_regression/3/abalone/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_regression/3/abalone/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_regression/3/abalone/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_regression/3/abalone/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_regression/3/abalone/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_regression/3/abalone/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_regression/3/abalone/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_regression/3/abalone/GATREE/gatree_hof_seed_3.pkl
#   inflating: results/baselines_regression/3/abalone/GATREE/gatree_search_populations_seed_3.pkl
#   inflating: results/baselines_regression/3/abalone/GATREE/gatree_search_populations_seed_1.pkl
#    creating: results/baselines_regression/3/abalone/CART/
#   inflating: results/baselines_regression/3/abalone/CART/results_seed_3.json
#   inflating: results/baselines_regression/3/abalone/CART/results_seed_0.json
#   inflating: results/baselines_regression/3/abalone/CART/results_seed_1.json
#   inflating: results/baselines_regression/3/abalone/CART/results_seed_2.json
#   inflating: results/baselines_regression/3/abalone/CART/results_seed_4.json
#    creating: results/baselines_regression/3/wine/
#    creating: results/baselines_regression/3/wine/GATREE/
#   inflating: results/baselines_regression/3/wine/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_regression/3/wine/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_regression/3/wine/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_regression/3/wine/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_regression/3/wine/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_regression/3/wine/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_regression/3/wine/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_regression/3/wine/GATREE/gatree_hof_seed_3.pkl
#   inflating: results/baselines_regression/3/wine/GATREE/gatree_search_populations_seed_3.pkl
#   inflating: results/baselines_regression/3/wine/GATREE/gatree_search_populations_seed_1.pkl
#    creating: results/baselines_regression/3/wine/CART/
#   inflating: results/baselines_regression/3/wine/CART/results_seed_3.json
#   inflating: results/baselines_regression/3/wine/CART/results_seed_0.json
#   inflating: results/baselines_regression/3/wine/CART/results_seed_1.json
#   inflating: results/baselines_regression/3/wine/CART/results_seed_2.json
#   inflating: results/baselines_regression/3/wine/CART/results_seed_4.json
#    creating: results/baselines_regression/3/cholesterol/
#    creating: results/baselines_regression/3/cholesterol/GATREE/
#   inflating: results/baselines_regression/3/cholesterol/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_regression/3/cholesterol/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_regression/3/cholesterol/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_regression/3/cholesterol/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_regression/3/cholesterol/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_regression/3/cholesterol/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_regression/3/cholesterol/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_regression/3/cholesterol/GATREE/gatree_hof_seed_3.pkl
#   inflating: results/baselines_regression/3/cholesterol/GATREE/gatree_search_populations_seed_3.pkl
#   inflating: results/baselines_regression/3/cholesterol/GATREE/gatree_search_populations_seed_1.pkl
#    creating: results/baselines_regression/3/cholesterol/CART/
#   inflating: results/baselines_regression/3/cholesterol/CART/results_seed_3.json
#   inflating: results/baselines_regression/3/cholesterol/CART/results_seed_0.json
#   inflating: results/baselines_regression/3/cholesterol/CART/results_seed_1.json
#   inflating: results/baselines_regression/3/cholesterol/CART/results_seed_2.json
#   inflating: results/baselines_regression/3/cholesterol/CART/results_seed_4.json
#    creating: results/baselines_regression/3/cars/
#    creating: results/baselines_regression/3/cars/GATREE/
#   inflating: results/baselines_regression/3/cars/GATREE/gatree_search_populations_seed_0.pkl
#   inflating: results/baselines_regression/3/cars/GATREE/gatree_search_populations_seed_2.pkl
#   inflating: results/baselines_regression/3/cars/GATREE/gatree_hof_seed_1.pkl
#   inflating: results/baselines_regression/3/cars/GATREE/gatree_hof_seed_4.pkl
#   inflating: results/baselines_regression/3/cars/GATREE/gatree_search_populations_seed_4.pkl
#   inflating: results/baselines_regression/3/cars/GATREE/gatree_hof_seed_2.pkl
#   inflating: results/baselines_regression/3/cars/GATREE/gatree_hof_seed_0.pkl
#   inflating: results/baselines_regression/3/cars/GATREE/gatree_hof_seed_3.pkl
# ...
#   inflating: results/llego_classification/breast/3/4/llego/llego_hof.pkl
#    creating: results/llego_classification/breast/4/
#    creating: results/llego_classification/breast/4/2/
#    creating: results/llego_classification/breast/4/2/llego/
#   inflating: results/llego_classification/breast/4/2/llego/llego_hof.pkl
#    creating: results/llego_classification/breast/4/1/
#    creating: results/llego_classification/breast/4/1/llego/
#   inflating: results/llego_classification/breast/4/1/llego/llego_hof.pkl
#    creating: results/llego_classification/breast/4/3/
#    creating: results/llego_classification/breast/4/3/llego/
#   inflating: results/llego_classification/breast/4/3/llego/llego_hof.pkl
#    creating: results/llego_classification/breast/4/0/
#    creating: results/llego_classification/breast/4/0/llego/
#   inflating: results/llego_classification/breast/4/0/llego/llego_hof.pkl
#    creating: results/llego_classification/breast/4/4/
#    creating: results/llego_classification/breast/4/4/llego/
#   inflating: results/llego_classification/breast/4/4/llego/llego_hof.pkl
#    creating: results/llego_classification/heart-statlog/
#    creating: results/llego_classification/heart-statlog/3/
#    creating: results/llego_classification/heart-statlog/3/2/
#    creating: results/llego_classification/heart-statlog/3/2/llego/
#   inflating: results/llego_classification/heart-statlog/3/2/llego/llego_hof.pkl
#    creating: results/llego_classification/heart-statlog/3/1/
#    creating: results/llego_classification/heart-statlog/3/1/llego/
#   inflating: results/llego_classification/heart-statlog/3/1/llego/llego_hof.pkl
#    creating: results/llego_classification/heart-statlog/3/3/
#    creating: results/llego_classification/heart-statlog/3/3/llego/
#   inflating: results/llego_classification/heart-statlog/3/3/llego/llego_hof.pkl
#    creating: results/llego_classification/heart-statlog/3/0/
#    creating: results/llego_classification/heart-statlog/3/0/llego/
#   inflating: results/llego_classification/heart-statlog/3/0/llego/llego_hof.pkl
#    creating: results/llego_classification/heart-statlog/3/4/
#    creating: results/llego_classification/heart-statlog/3/4/llego/
#   inflating: results/llego_classification/heart-statlog/3/4/llego/llego_hof.pkl
#    creating: results/llego_classification/heart-statlog/4/
#    creating: results/llego_classification/heart-statlog/4/2/
#    creating: results/llego_classification/heart-statlog/4/2/llego/
#   inflating: results/llego_classification/heart-statlog/4/2/llego/llego_hof.pkl
#    creating: results/llego_classification/heart-statlog/4/1/
#    creating: results/llego_classification/heart-statlog/4/1/llego/
#   inflating: results/llego_classification/heart-statlog/4/1/llego/llego_hof.pkl
#    creating: results/llego_classification/heart-statlog/4/3/
#    creating: results/llego_classification/heart-statlog/4/3/llego/
#   inflating: results/llego_classification/heart-statlog/4/3/llego/llego_hof.pkl
#    creating: results/llego_classification/heart-statlog/4/0/
#    creating: results/llego_classification/heart-statlog/4/0/llego/
#   inflating: results/llego_classification/heart-statlog/4/0/llego/llego_hof.pkl
#    creating: results/llego_classification/heart-statlog/4/4/
#    creating: results/llego_classification/heart-statlog/4/4/llego/
#   inflating: results/llego_classification/heart-statlog/4/4/llego/llego_hof.pkl
#    creating: results/llego_classification/vehicle/
#    creating: results/llego_classification/vehicle/3/
#    creating: results/llego_classification/vehicle/3/2/
#    creating: results/llego_classification/vehicle/3/2/llego/
#   inflating: results/llego_classification/vehicle/3/2/llego/llego_hof.pkl
#    creating: results/llego_classification/vehicle/3/1/
#    creating: results/llego_classification/vehicle/3/1/llego/
#   inflating: results/llego_classification/vehicle/3/1/llego/llego_hof.pkl
#    creating: results/llego_classification/vehicle/3/3/
#    creating: results/llego_classification/vehicle/3/3/llego/
#   inflating: results/llego_classification/vehicle/3/3/llego/llego_hof.pkl
#    creating: results/llego_classification/vehicle/3/0/
#    creating: results/llego_classification/vehicle/3/0/llego/
#   inflating: results/llego_classification/vehicle/3/0/llego/llego_hof.pkl
#    creating: results/llego_classification/vehicle/3/4/
#    creating: results/llego_classification/vehicle/3/4/llego/
#   inflating: results/llego_classification/vehicle/3/4/llego/llego_hof.pkl
#    creating: results/llego_classification/vehicle/4/
#    creating: results/llego_classification/vehicle/4/2/
#    creating: results/llego_classification/vehicle/4/2/llego/
#   inflating: results/llego_classification/vehicle/4/2/llego/data.pkl
#   inflating: results/llego_classification/vehicle/4/2/llego/meta_data.pkl
#   inflating: results/llego_classification/vehicle/4/2/llego/llego_hof.pkl
#    creating: results/llego_classification/vehicle/4/1/
#    creating: results/llego_classification/vehicle/4/1/llego/
#   inflating: results/llego_classification/vehicle/4/1/llego/llego_hof.pkl
#    creating: results/llego_classification/vehicle/4/3/
#    creating: results/llego_classification/vehicle/4/3/llego/
#   inflating: results/llego_classification/vehicle/4/3/llego/data.pkl
#   inflating: results/llego_classification/vehicle/4/3/llego/meta_data.pkl
#   inflating: results/llego_classification/vehicle/4/3/llego/llego_hof.pkl
#    creating: results/llego_classification/vehicle/4/0/
#    creating: results/llego_classification/vehicle/4/0/llego/
#   inflating: results/llego_classification/vehicle/4/0/llego/llego_hof.pkl
#    creating: results/llego_classification/vehicle/4/4/
#    creating: results/llego_classification/vehicle/4/4/llego/
#   inflating: results/llego_classification/vehicle/4/4/llego/llego_hof.pkl
#    creating: results/llego_regression/abalone/
#    creating: results/llego_regression/abalone/3/
#    creating: results/llego_regression/abalone/3/2/
#    creating: results/llego_regression/abalone/3/2/llego/
#   inflating: results/llego_regression/abalone/3/2/llego/llego_hof.pkl
#    creating: results/llego_regression/abalone/3/1/
#    creating: results/llego_regression/abalone/3/1/llego/
#   inflating: results/llego_regression/abalone/3/1/llego/llego_hof.pkl
#    creating: results/llego_regression/abalone/3/3/
#    creating: results/llego_regression/abalone/3/3/llego/
#   inflating: results/llego_regression/abalone/3/3/llego/data.pkl
#   inflating: results/llego_regression/abalone/3/3/llego/meta_data.pkl
#   inflating: results/llego_regression/abalone/3/3/llego/llego_hof.pkl
#    creating: results/llego_regression/abalone/3/0/
#    creating: results/llego_regression/abalone/3/0/llego/
#   inflating: results/llego_regression/abalone/3/0/llego/llego_hof.pkl
#    creating: results/llego_regression/abalone/3/4/
#    creating: results/llego_regression/abalone/3/4/llego/
#   inflating: results/llego_regression/abalone/3/4/llego/llego_hof.pkl
#    creating: results/llego_regression/abalone/4/
#    creating: results/llego_regression/abalone/4/2/
#    creating: results/llego_regression/abalone/4/2/llego/
#   inflating: results/llego_regression/abalone/4/2/llego/llego_hof.pkl
#    creating: results/llego_regression/abalone/4/1/
#    creating: results/llego_regression/abalone/4/1/llego/
#   inflating: results/llego_regression/abalone/4/1/llego/llego_hof.pkl
#    creating: results/llego_regression/abalone/4/3/
#    creating: results/llego_regression/abalone/4/3/llego/
#   inflating: results/llego_regression/abalone/4/3/llego/llego_hof.pkl
#    creating: results/llego_regression/abalone/4/0/
#    creating: results/llego_regression/abalone/4/0/llego/
#   inflating: results/llego_regression/abalone/4/0/llego/llego_hof.pkl
#    creating: results/llego_regression/abalone/4/4/
#    creating: results/llego_regression/abalone/4/4/llego/
#   inflating: results/llego_regression/abalone/4/4/llego/llego_hof.pkl
#    creating: results/llego_regression/wine/
#    creating: results/llego_regression/wine/3/
#    creating: results/llego_regression/wine/3/2/
#    creating: results/llego_regression/wine/3/2/llego/
#   inflating: results/llego_regression/wine/3/2/llego/llego_hof.pkl
#    creating: results/llego_regression/wine/3/1/
#    creating: results/llego_regression/wine/3/1/llego/
#   inflating: results/llego_regression/wine/3/1/llego/llego_hof.pkl
#    creating: results/llego_regression/wine/3/3/
#    creating: results/llego_regression/wine/3/3/llego/
#   inflating: results/llego_regression/wine/3/3/llego/llego_hof.pkl
#    creating: results/llego_regression/wine/3/0/
#    creating: results/llego_regression/wine/3/0/llego/
#   inflating: results/llego_regression/wine/3/0/llego/llego_hof.pkl
#    creating: results/llego_regression/wine/3/4/
#    creating: results/llego_regression/wine/3/4/llego/
#   inflating: results/llego_regression/wine/3/4/llego/llego_hof.pkl
#    creating: results/llego_regression/wine/4/
#    creating: results/llego_regression/wine/4/2/
#    creating: results/llego_regression/wine/4/2/llego/
#   inflating: results/llego_regression/wine/4/2/llego/llego_hof.pkl
#    creating: results/llego_regression/wine/4/1/
#    creating: results/llego_regression/wine/4/1/llego/
#   inflating: results/llego_regression/wine/4/1/llego/llego_hof.pkl
#    creating: results/llego_regression/wine/4/3/
#    creating: results/llego_regression/wine/4/3/llego/
#   inflating: results/llego_regression/wine/4/3/llego/llego_hof.pkl
#    creating: results/llego_regression/wine/4/0/
#    creating: results/llego_regression/wine/4/0/llego/
#   inflating: results/llego_regression/wine/4/0/llego/llego_hof.pkl
#    creating: results/llego_regression/wine/4/4/
#    creating: results/llego_regression/wine/4/4/llego/
#   inflating: results/llego_regression/wine/4/4/llego/data.pkl
#   inflating: results/llego_regression/wine/4/4/llego/meta_data.pkl
#   inflating: results/llego_regression/wine/4/4/llego/llego_hof.pkl
#    creating: results/llego_regression/cholesterol/
#    creating: results/llego_regression/cholesterol/3/
#    creating: results/llego_regression/cholesterol/3/2/
#    creating: results/llego_regression/cholesterol/3/2/llego/
#   inflating: results/llego_regression/cholesterol/3/2/llego/llego_hof.pkl
#    creating: results/llego_regression/cholesterol/3/1/
#    creating: results/llego_regression/cholesterol/3/1/llego/
#   inflating: results/llego_regression/cholesterol/3/1/llego/llego_hof.pkl
#    creating: results/llego_regression/cholesterol/3/3/
#    creating: results/llego_regression/cholesterol/3/3/llego/
#   inflating: results/llego_regression/cholesterol/3/3/llego/llego_hof.pkl
#    creating: results/llego_regression/cholesterol/3/0/
#    creating: results/llego_regression/cholesterol/3/0/llego/
#   inflating: results/llego_regression/cholesterol/3/0/llego/llego_hof.pkl
#    creating: results/llego_regression/cholesterol/3/4/
#    creating: results/llego_regression/cholesterol/3/4/llego/
#   inflating: results/llego_regression/cholesterol/3/4/llego/llego_hof.pkl
#    creating: results/llego_regression/cholesterol/4/
#    creating: results/llego_regression/cholesterol/4/2/
#    creating: results/llego_regression/cholesterol/4/2/llego/
#   inflating: results/llego_regression/cholesterol/4/2/llego/llego_hof.pkl
#    creating: results/llego_regression/cholesterol/4/1/
#    creating: results/llego_regression/cholesterol/4/1/llego/
#   inflating: results/llego_regression/cholesterol/4/1/llego/llego_hof.pkl
#    creating: results/llego_regression/cholesterol/4/3/
#    creating: results/llego_regression/cholesterol/4/3/llego/
#   inflating: results/llego_regression/cholesterol/4/3/llego/llego_hof.pkl
#    creating: results/llego_regression/cholesterol/4/0/
#    creating: results/llego_regression/cholesterol/4/0/llego/
#   inflating: results/llego_regression/cholesterol/4/0/llego/llego_hof.pkl
#    creating: results/llego_regression/cholesterol/4/4/
#    creating: results/llego_regression/cholesterol/4/4/llego/
#   inflating: results/llego_regression/cholesterol/4/4/llego/llego_hof.pkl
#    creating: results/llego_regression/cars/
#    creating: results/llego_regression/cars/3/
#    creating: results/llego_regression/cars/3/2/
#    creating: results/llego_regression/cars/3/2/llego/
#   inflating: results/llego_regression/cars/3/2/llego/llego_hof.pkl
#    creating: results/llego_regression/cars/3/1/
#    creating: results/llego_regression/cars/3/1/llego/
#   inflating: results/llego_regression/cars/3/1/llego/llego_hof.pkl
#    creating: results/llego_regression/cars/3/3/
#    creating: results/llego_regression/cars/3/3/llego/
#   inflating: results/llego_regression/cars/3/3/llego/data.pkl
#   inflating: results/llego_regression/cars/3/3/llego/meta_data.pkl
#   inflating: results/llego_regression/cars/3/3/llego/llego_hof.pkl
#    creating: results/llego_regression/cars/3/0/
#    creating: results/llego_regression/cars/3/0/llego/
#   inflating: results/llego_regression/cars/3/0/llego/llego_hof.pkl
#    creating: results/llego_regression/cars/3/4/
#    creating: results/llego_regression/cars/3/4/llego/
#   inflating: results/llego_regression/cars/3/4/llego/llego_hof.pkl
#    creating: results/llego_regression/cars/4/
#    creating: results/llego_regression/cars/4/2/
#    creating: results/llego_regression/cars/4/2/llego/
#   inflating: results/llego_regression/cars/4/2/llego/llego_hof.pkl
#    creating: results/llego_regression/cars/4/1/
#    creating: results/llego_regression/cars/4/1/llego/
#   inflating: results/llego_regression/cars/4/1/llego/llego_hof.pkl
#    creating: results/llego_regression/cars/4/3/
#    creating: results/llego_regression/cars/4/3/llego/
#   inflating: results/llego_regression/cars/4/3/llego/llego_hof.pkl
#    creating: results/llego_regression/cars/4/0/
#    creating: results/llego_regression/cars/4/0/llego/
#   inflating: results/llego_regression/cars/4/0/llego/data.pkl
#   inflating: results/llego_regression/cars/4/0/llego/meta_data.pkl
#   inflating: results/llego_regression/cars/4/0/llego/llego_hof.pkl
#    creating: results/llego_regression/cars/4/4/
#    creating: results/llego_regression/cars/4/4/llego/
#   inflating: results/llego_regression/cars/4/4/llego/llego_hof.pkl
#    creating: results/llego_regression/wage/
#    creating: results/llego_regression/wage/3/
#    creating: results/llego_regression/wage/3/2/
#    creating: results/llego_regression/wage/3/2/llego/
#   inflating: results/llego_regression/wage/3/2/llego/llego_hof.pkl
#    creating: results/llego_regression/wage/3/1/
#    creating: results/llego_regression/wage/3/1/llego/
#   inflating: results/llego_regression/wage/3/1/llego/llego_hof.pkl
#    creating: results/llego_regression/wage/3/3/
#    creating: results/llego_regression/wage/3/3/llego/
#   inflating: results/llego_regression/wage/3/3/llego/llego_hof.pkl
#    creating: results/llego_regression/wage/3/0/
#    creating: results/llego_regression/wage/3/0/llego/
#   inflating: results/llego_regression/wage/3/0/llego/llego_hof.pkl
#    creating: results/llego_regression/wage/3/4/
#    creating: results/llego_regression/wage/3/4/llego/
#   inflating: results/llego_regression/wage/3/4/llego/llego_hof.pkl
#    creating: results/llego_regression/wage/4/
#    creating: results/llego_regression/wage/4/2/
#    creating: results/llego_regression/wage/4/2/llego/
#   inflating: results/llego_regression/wage/4/2/llego/llego_hof.pkl
#    creating: results/llego_regression/wage/4/1/
#    creating: results/llego_regression/wage/4/1/llego/
#   inflating: results/llego_regression/wage/4/1/llego/llego_hof.pkl
#    creating: results/llego_regression/wage/4/3/
#    creating: results/llego_regression/wage/4/3/llego/
#   inflating: results/llego_regression/wage/4/3/llego/llego_hof.pkl
#    creating: results/llego_regression/wage/4/0/
#    creating: results/llego_regression/wage/4/0/llego/
#   inflating: results/llego_regression/wage/4/0/llego/data.pkl
#   inflating: results/llego_regression/wage/4/0/llego/meta_data.pkl
#   inflating: results/llego_regression/wage/4/0/llego/llego_hof.pkl
#    creating: results/llego_regression/wage/4/4/
#    creating: results/llego_regression/wage/4/4/llego/
#   inflating: results/llego_regression/wage/4/4/llego/llego_hof.pkl

# %% [markdown]
# # Classification

# %% [markdown]
# ### Baselines

# %%
def read_results_baselines(datasets, depths, seeds, methods_config, base_path="./results", folder_name="baselines_classification"):
    
    
    results_data = []
    
    # Process each method
    for depth in depths:
        for method in methods_config:
            config = methods_config[method]
            metric_key = config["metric_key"]
            ordering = config["ordering"]
            
            for dataset in datasets:
                for seed in seeds:
                    # Construct the file path
                    file_pattern = config["file_pattern"].format(seed=seed)
                    file_path = Path(base_path) / folder_name / depth / dataset / method / file_pattern
                    
                    try:
                        # Read and extract result based on method type
                        if config["result_type"] == "json":
                            with open(file_path, "r") as f:
                                result_json = json.load(f)
                            
                            # Navigate through nested dictionary to get the result
                            result_value = result_json
                            for key in config["result_key"]:
                                result_value = result_value[key]
                            
                            metric = result_value
                            
                        elif config["result_type"] == "pkl":
                            with open(file_path, "rb") as f:
                                result_pkl = pkl.load(f)
                            
                            # Extract best individual from the last iteration
                            last_iter = config["last_iter"]
                            population = result_pkl[last_iter]["population"]
                            
                            # Sort by fitness function
                            sorting_function = lambda x: (x.fitness[f"{metric_key}_train"] + 
                                                         2 * x.fitness[f"{metric_key}_val"])
                            reverse = True if ordering == "max" else False
                            population.sort(key=sorting_function, reverse=reverse)
                            
                            best_ind = population[0]
                            metric = best_ind.fitness[f"{metric_key}_test"]
                        
                        # Store the result
                        results_data.append({
                            "depth": depth,
                            "method": method,
                            "dataset": dataset,
                            "seed": seed,
                            metric_key: metric
                        })
                        
                    except Exception as e:
                        print(f"Error reading {file_path}: {str(e)}")
                        # Add a row with NaN for balanced_accuracy
                        results_data.append({
                            "depth": depth,
                            "method": method,
                            "dataset": dataset,
                            "seed": seed,
                            metric_key: np.nan
                        })
    
    # Convert to DataFrame
    results_df = pd.DataFrame(results_data)
    return results_df

def read_results_llego(datasets, depths, seeds, methods_config, base_path="/home/nvth2/llego/results", folder_name="llego_classification"):
    
    # Initialize an empty list to collect results
    results_data = []
    metric_key = methods_config["LLEGO"]["metric_key"]
    ordering = methods_config["LLEGO"]["ordering"]
    
    for dataset in datasets:
        for depth in depths:
            for seed in seeds:
                # Construct the file path
                file_path = Path(base_path) / folder_name / dataset / depth / str(seed) / "llego" / "llego_hof.pkl"
                
                try:
                    # Read the hall of fame pickle file
                    with open(file_path, "rb") as f:
                        hof = pkl.load(f)
                    
                    # Calculate average fitness for each individual
                    average_fitness = [(0.5 * ind.fitness[f'{metric_key}_train'] + 
                                        ind.fitness[f'{metric_key}_val']) / 2 
                                       for ind in hof]
                    
                    # Find the index of the best individual
                    best_index = average_fitness.index(max(average_fitness)) if ordering == "max" else average_fitness.index(min(average_fitness))
                    
                    # Get the best individual
                    best_ind = hof[best_index]
                    
                    # Extract the metric
                    metric = best_ind.fitness[f"{metric_key}_test"]
                    
                    # Store the result
                    results_data.append({
                        "depth": depth,
                        "method": "LLEGO",  # Adding method name for consistency
                        "dataset": dataset,
                        "seed": seed,
                        metric_key: metric
                    })
                    
                except Exception as e:
                    print(f"Error reading {file_path}: {str(e)}")
                    results_data.append({
                        "depth": depth,
                        "method": "LLEGO",
                        "dataset": dataset,
                        "seed": seed,
                        metric_key: np.nan
                    })
    
    # Convert to DataFrame
    results_df = pd.DataFrame(results_data)
    return results_df

def combine_all_results(datasets, depths, seeds, baselines_config, llego_config, base_path="./results", folder_name_baselines="baselines_classification", folder_name_llego="llego_classification"):
    # Get baseline results
    baseline_results = read_results_baselines(
        datasets=datasets, 
        depths=depths, 
        seeds=seeds, 
        methods_config=baselines_config,
        base_path=base_path, 
        folder_name=folder_name_baselines
    )
    
    # Get LLEGO results
    llego_results = read_results_llego(
        datasets=datasets, 
        depths=depths, 
        seeds=seeds, 
        methods_config=llego_config,
        base_path=base_path, 
        folder_name=folder_name_llego
    )
    
    # Combine the results
    combined_results = pd.concat([baseline_results, llego_results], ignore_index=True)
    
    return combined_results

def compute_summary_statistics(results_df, metric_key):
    
    # Group by depth, method, and dataset, then calculate mean and std
    summary = results_df.groupby(['depth', 'method', 'dataset'])[metric_key].agg(['mean', 'std']).reset_index()
    
    return summary


# Define constants
datasets = ["breast", "compas", "credit-g", "diabetes", "heart-statlog", "liver", "vehicle"]
depths = ["3", "4"]
seeds = list(range(5))  
metric_key = "balanced_accuracy"
ordering = "max"
baselines_config = {
        "CART": {
            "file_pattern": "results_seed_{seed}.json",
            "result_type": "json",
            "result_key": ["test", "balanced_accuracy"],
            "metric_key": metric_key,
            "ordering": ordering
        },
        "DL85": {
            "file_pattern": "results_seed_{seed}.json",
            "result_type": "json",
            "result_key": ["test", "balanced_accuracy"],
            "metric_key": metric_key,
            "ordering": ordering
        },
        "GOSDT": {
            "file_pattern": "results_seed_{seed}.json",
            "result_type": "json", 
            "result_key": ["test", "balanced_accuracy"],
            "metric_key": metric_key,
            "ordering": ordering
        },
        "C45": {
            "file_pattern": "results_seed_{seed}.json",
            "result_type": "json",
            "result_key": ["test", "balanced_accuracy"],
            "metric_key": metric_key,
            "ordering": ordering
        },
        # GATREE method (pickle results)
        "GATREE": {
            "file_pattern": "gatree_search_populations_seed_{seed}.pkl",
            "result_type": "pkl",
            "last_iter": 25,
            "metric_key": metric_key,
            "ordering": ordering
        },
        
    }

llego_config = {
    "LLEGO": {
        "metric_key": metric_key,
        "ordering": ordering
    }
}

# Read all results
print("Reading results...")
results_df_clas = combine_all_results(datasets, depths, seeds, baselines_config, llego_config, base_path="./results", folder_name_baselines="baselines_classification", folder_name_llego="llego_classification")
# Save the raw results
results_df_clas.to_csv("artifacts/all_classification_results.csv", index=False)
print(f"Raw results saved to all_classification_results.csv")

# Compute summary statistics
summary_df_clas = compute_summary_statistics(results_df_clas, metric_key)
summary_df_clas.to_csv("artifacts/summary_classification_results.csv", index=False)
print(f"Summary results saved to summary_classification_results.csv")

# Print some basic information
print("\nResults overview:")
print(f"Total results: {len(results_df_clas)}")
print(f"Missing values: {results_df_clas['balanced_accuracy'].isna().sum()}")

# Print final joint summary
print("\nJoint summary by depth-method-dataset:")
print(summary_df_clas.head())
# Out:
# Reading results...
# Raw results saved to all_classification_results.csv
# Summary results saved to summary_classification_results.csv
#
# Results overview:
# Total results: 420
# Missing values: 0
#
# Joint summary by depth-method-dataset:
#   depth method        dataset      mean       std
# 0     3    C45         breast  0.938444  0.012256
# 1     3    C45         compas  0.649984  0.008806
# 2     3    C45       credit-g  0.579072  0.029993
# 3     3    C45       diabetes  0.686564  0.044992
# 4     3    C45  heart-statlog  0.704418  0.018522

# %% [markdown]
# ### Compute ranks

# %%
def compute_method_ranks(summary_df, depth):
    # Filter by the specified depth
    depth_df = summary_df[summary_df['depth'] == depth].copy()
    
    # Create a list to store rank results
    rank_results = []
    
    # Process each dataset
    for dataset in depth_df['dataset'].unique():
        # Get data for this dataset
        dataset_df = depth_df[depth_df['dataset'] == dataset]
        
        # Skip datasets with too few methods (need at least 2 for ranking)
        if len(dataset_df) < 2:
            continue
            
        ranks = stats.rankdata(-dataset_df['mean'].values)  # Negative for descending order
        
        # Add ranks to the results
        for i, (_, row) in enumerate(dataset_df.iterrows()):
            rank_results.append({
                'method': row['method'],
                'dataset': dataset,
                'rank': ranks[i]
            })
    
    rank_df = pd.DataFrame(rank_results)
    
    method_ranks = rank_df.groupby('method')['rank'].agg(['mean', 'std', 'count']).reset_index()
    
    method_ranks = method_ranks.sort_values('mean')
    
    return method_ranks

# Compute ranks for each depth
depth_ranks = {}
for depth in depths:
    depth_ranks[depth] = compute_method_ranks(summary_df_clas, depth)
    
# Print the ranks
for depth, ranks in depth_ranks.items():
    print(f"\nRanks for depth {depth}:")
    print(ranks)
    print("\n")
# Out:
# Ranks for depth 3:
#    method      mean       std  count
# 5   LLEGO  1.571429  0.786796      7
# 1    CART  2.857143  0.899735      7
# 2    DL85  3.000000  1.732051      7
# 3  GATREE  4.285714  1.112697      7
# 4   GOSDT  4.428571  2.149197      7
# 0     C45  4.857143  1.069045      7
#
#
#
# Ranks for depth 4:
#    method      mean       std  count
# 5   LLEGO  1.000000  0.000000      7
# 1    CART  2.857143  0.899735      7
# 0     C45  3.571429  1.133893      7
# 4   GOSDT  4.285714  1.889822      7
# 3  GATREE  4.571429  0.975900      7
# 2    DL85  4.714286  1.496026      7

# %% [markdown]
# ### Regression results

# %%
# Define constants
datasets = ["abalone", "cars", "cholesterol", "wage", "wine"]
depths = ["3", "4"]
seeds = list(range(5))  # [0, 1, 2, 3, 4]
metric_key = "mse"
ordering = "min"
baselines_config = {
        # Standard methods (JSON results)
        "CART": {
            "file_pattern": "results_seed_{seed}.json",
            "result_type": "json",
            "result_key": ["test", metric_key],
            "metric_key": metric_key,
            "ordering": ordering
        },
        "GATREE": {
            "file_pattern": "gatree_search_populations_seed_{seed}.pkl",
            "result_type": "pkl",
            "last_iter": 25,
            "metric_key": metric_key,
            "ordering": ordering
        },
        
    }

llego_config = {
    "LLEGO": {
        "metric_key": metric_key,
        "ordering": ordering
    }
}

# Read all results
print("Reading results...")
results_df_reg = combine_all_results(datasets, depths, seeds, baselines_config, llego_config, base_path="./results", folder_name_baselines="baselines_regression", folder_name_llego="llego_regression")
# Save the raw results
results_df_reg.to_csv("artifacts/all_regression_results.csv", index=False)


# Compute summary statistics
summary_df_reg = compute_summary_statistics(results_df_reg, metric_key)
summary_df_reg.to_csv("artifacts/summary_regression_results.csv", index=False)

# Print some basic information
print("\nResults overview:")
print(f"Total results: {len(results_df_reg)}")
print(f"Missing values: {results_df_reg[metric_key].isna().sum()}")

# Print final joint summary
print("\nJoint summary by depth-method-dataset:")
print(summary_df_reg.head())
# Out:
# Reading results...
#
# Results overview:
# Total results: 150
# Missing values: 0
#
# Joint summary by depth-method-dataset:
#   depth method      dataset      mean       std
# 0     3   CART      abalone  0.590940  0.026640
# 1     3   CART         cars  0.250238  0.028289
# 2     3   CART  cholesterol  1.499609  0.244148
# 3     3   CART         wage  1.036427  0.145610
# 4     3   CART         wine  0.810960  0.008608
